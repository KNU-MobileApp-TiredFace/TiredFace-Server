# %% [markdown]
# # Face Detection Test
#
# `OpenCV`로 Face Detection 테스트한 기록입니다.
#
# ## References
#
# * [opencv install](https://pypi.org/project/opencv-python/)
# * [FACE DETECTION USING OPENCV AND PYTHON: A BEGINNER’S GUIDE](https://www.superdatascience.com/opencv-face-detection/)
# * [How to Display a Matplotlib RGB Image](https://www.pyimagesearch.com/2014/11/03/display-matplotlib-rgb-image/)
#
#
# ## Source of Data
#
# * [네이버 영화: 다크나이트](https://movie.naver.com/movie/bi/mi/photoView.nhn?code=62586)
# * [OpenCV xml data](https://github.com/informramiz/Face-Detection-OpenCV)

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# %%
img = cv2.imread("./joker.jpg")
plt.imshow(img)

# %%
type(img)
# Out:
# numpy.ndarray

# %%
img.shape
# Out:
# (443, 326, 3)

# %%
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
plt.imshow(img)

# %%
#load cascade classifier training file for haarcascade 
haar_face_cascade = cv2.CascadeClassifier('./haarcascade_frontalface_alt.xml')

# %%
def detect_faces(f_cascade, colored_img, scaleFactor = 1.1):
    #just making a copy of image passed, so that passed image is not changed 
    img_copy = colored_img.copy()          

    #convert the test image to gray image as opencv face detector expects gray images
    gray = cv2.cvtColor(img_copy, cv2.COLOR_RGB2GRAY)          

    #let's detect multiscale (some images may be closer to camera than others) images
    faces = f_cascade.detectMultiScale(gray, scaleFactor=scaleFactor, minNeighbors=5);          

    #go over list of faces and draw them as rectangles on original colored img
    for (x, y, w, h) in faces:
        print(x, y, w, h)
        cv2.rectangle(img_copy, (x, y), (x+w, y+h), (0, 255, 0), 2)              

    return img_copy

# %%
img_face = detect_faces(haar_face_cascade, img)
plt.imshow(img_face)
# Out:
# 113 61 77 77

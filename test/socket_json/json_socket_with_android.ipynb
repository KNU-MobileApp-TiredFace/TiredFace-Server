# %% [markdown]
# ## JSON 소켓 통신 with Android
#
# 소켓통신을 해보았고 다음과 같은 이슈가 있었습니다.
#
# ### Reading Messages
#
# JSON bytes stream을 받을 때, 실시간으로 고용량을 보내기 때문에 들어오는 크기가 제각각 이였습니다.
#
# 따라서 JSON 마지막 구분자 `}`가 들어올 때 까지 무작정 받기로 했습니다.
#
# (대신 string concat 메모리 비효율 문제가 있음)
#
# ###  Message re-encoding issue
#
# 메세지를 다시 base64로 인코딩을 할때, numpy array에서 base64모듈을 사용해 인코딩을 하는데
#
# 크기가 5배 가까이 증가하는 현상을 보임, 이후 해결해야할 과제로 보이나,
#
# 일단 안드로이드가 받은 메세지를 이미지로 번역하는 과정을 기다려야함.

# %% [markdown]
# ## 서버열고 안드로이드에서 받음

# %%
import json
import socket
import base64
import io
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import numpy as np
import cv2
import PIL

# %%
PORT = 12321
HOST = '192.168.0.2'
BACKLOG = 10

s = socket.socket(socket.AF_INET, socket.SOCK_STREAM)
s.bind((HOST, PORT))
s.listen(BACKLOG)
conn, addr = s.accept()
conn, addr

# %%
all_msg = ""
PACKET_LEN = 1024 ** 2

# %%
while all_msg[-1:] != "}":
    while True:
        temp = conn.recv(PACKET_LEN)
        print(len(temp))
        all_msg += temp.decode('utf-8')
        if len(temp) < PACKET_LEN:
            break
        
len(all_msg), type(all_msg), all_msg
# Out:
# 131220
# 180
# 264260
# 4380
# 4380
# 121180
# 5840
# 4380
# 4380
# 41432
# 55035
# (636667,
#  str,
#  '{"msgId":"1","encodedType":"base64","image":"\nB2/ANuys3i0Tq6NXcOqnsFr+MXRFj8fk8QFKoSNQSGPounk6K5ISC ...

# %%
conn.close()
s.close()

# %%
len(all_msg)
# Out:
# 636667

# %%
split_msg = all_msg.split('"')

for i, msg in enumerate(split_msg):
    print(i, len(msg))
# Out:
# 0 1
# 1 5
# 2 1
# 3 1
# 4 1
# 5 11
# 6 1
# 7 6
# 8 1
# 9 5
# 10 1
# 11 636620
# 12 1

# %%
base_code = "".join(split_msg[11:-1])
len(base_code)
# Out:
# 636620

# %%
base64_decode = base64.b64decode(base_code)
len(base64_decode)
# Out:
# 471262

# %%
type(base64_decode)
# Out:
# bytes

# %%
base64_decode[:10]
# Out:
# b'\xff\xd8\xff\xe0\x00\x10JFIF'

# %%
bytes_image = io.BytesIO(base64_decode)
img = mpimg.imread(bytes_image, format="JPG")

# %%
type(img)
# Out:
# numpy.ndarray

# %%
img.shape
# Out:
# (756, 1008, 3)

# %%
len(img.base)
# Out:
# 2286144

# %%
img.base[:1000]
# Out:
# b'k[ej]ghZkdWij[njZgjXXjXNkUHlWFnXKn[MlXMkYMgSJjVKhQChR=dL2dM.gL.fK-]B$]B$`E(^C&aE-_D)U;\x1aZ@\x1d[A\x1cV<\x17X>\x1dV<\x1bU8\x1aR5\x17U:\x1dU:\x1cR5\x15P3\x11P6\x13S9\x16R5\x13S7\x12T6\x12U8\x10T4\rV7\x0bU5\x06[;\nY7\x07\\:\nX7\n_>\x11\\<\r^>\x0f];\x0ba@\rhC\x0fe@\tlE\x0ei@\x08tJ\x10|O\x14|S\x11\x80X\x13\x87\\\x17\x87\\\x17\x89_\x17\x88^\x16\x85]\x18\x85]\x18\x83[\x16\x86^\x19\x86[\x17\x81V\x12\x80X\x13|T\x0f\x80X\x13\x80X\x13\x83[\x15{S\r}R\x0e|T\x0f}U\x10|U\x10{T\x11zS\x10vM\x0bzQ\x0fxO\r{R\x10vM\rsJ\x0crH\x0elA\x0ci=\x0ea5\x08_2\ta4\x0b_4\na6\x0cc6\x0fe8\x11c8\x0eb7\x0ce:\x0fd9\x0ca6\x0ch=\x13d:\x10^4\n_4\t`5\n`6\x0ea7\x0fb8\x10`6\x0ca6\x0cb7\x0ca8\x0c`7\ta6\tb8\x08a7\x05b8\x08_4\t_4\n_5\x0b\\3\x07]4\x08\\3\x05]2\x05]2\x07Z/\x05X.\x06[1\tT-\x04T-\x06W0\tU-\tQ)\x05V0\x0bN+\x05N*\x06K)\x04J)\x08L+\nG&\x05H\'\x06E$\x03G)\x07E&\tG*\x0cE(\nC&\x08C(\nC(\nF)\tC)\x08B(\x07C+\tB*\x08?\'\x05?\'\x03C+\x07I1\rJ2\x0eI3\x0cH2\x0bI1\x0fG/\rC,\nE.\x0cT>\x19]G"O9\x12G1\nE-\tC+\x07F.\x08T<\x16X>\x1bI/\x0cK,\rH)\nH\'\x08P/\x10H&\nF%\x06C$\x05D&\x04D%\x06C$\x05G%\tE&\tG(\x0bA$\x06A"\x03G(\tB\x1f\x01H\'\x08C!\x05B#\x06C$\x07? \x03C$\x08B$\x08B$\x08?$\x07@"\n> \x08A#\t?!\x07; \x05<!\x06<"\x07;!\x06?#\r;\x1f\t?#\x0b=!\t:\x1e\x06;!\x088\x1e\x079!\t< \n8\x1c\x069\x1f\x06;!\x08:"\x089!\x078\x1e\x05=#\n;#\t=%\x0b;&\t9$\x07;&\x07;&\x07;\'\x06;\'\x06>)\x0c9$\x07;(\n<)\x0b=*\nB/\x0e@0\x0eC3\x0fD4\x12D4\x12M>\x1fL=\x1eM>\x1dM>\x1dQB#N? P@&SC)QB%RC&UE+WG-UE+ZJ0ZK.UF)YI0XH/]L8WG0]M6ZJ1[K2]M3\\L2_P3bR9hX?k[BjZAk[Dk[Do_Hm]FkYAm\\BhX>l]@k[Bl\\Ck[Dl\\Cm\\Bm\\@p\\ChT;cR6_N2gV8aP4fR9bN5\\G*\\H\'bJ$cL"`K bM"ZD\x1f[D"ZD\x1f[E ZB ZB V>\x1cYA\x1fO6\x18S:\x1cR7\x19S8\x1aJ+\x0fR3\x17N/\x12H&\nK(\nI$\x07G$\x06J\'\tM)\tL(\x08O+\x0bN'

# %%
plt.imshow(img)
plt.show()

# %%
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
cv2.imwrite("./test_file.jpg", img)
# Out:
# True

# %% [markdown]
# ## 서버 열고 안드로이드로 전송

# %%
s = socket.socket(socket.AF_INET, socket.SOCK_STREAM)
s.bind((HOST, PORT))
s.listen(BACKLOG)
conn, addr = s.accept()
conn, addr

# %%
encoded_string = None
with open("./test_file.jpg", "rb") as image_file:
    encoded_string = base64.b64encode(image_file.read())

# %%
len(encoded_string)
# Out:
# 277344

# %%
type(encoded_string)
# Out:
# bytes

# %%
send_msg_dict = {
    "TiredScore": 0.98,
    "image": str(encoded_string)
}

# %%
json_msg = json.dumps(send_msg_dict)
type(json_msg), len(json_msg)
# Out:
# (str, 277380)

# %%
conn.sendall(json_msg.encode('utf-8'))

# %%
conn.close()
s.close()

# %% [markdown]
# ## Encoded image test

# %%
with open("encoded_text.txt", "w") as f:
    f.write(str(encoded_string))

# %%
str_encoded = str(encoded_string)

# %%
type(encoded_string), type(str_encoded)
# Out:
# (bytes, str)

# %%
str_encoded[:100]
# Out:
# "b'/9j/4AAQSkZJRgABAQAAAQABAAD/2wBDAAIBAQEBAQIBAQECAgICAgQDAgICAgUEBAMEBgUGBgYFBgYGBwkIBgcJBwYGCAsICQ"

# %%
for i, d in enumerate(str_encoded.split("'")):
    print(i, len(d))
# Out:
# 0 1
# 1 277344
# 2 0

# %%
str_encoded.split("'")[1][:10], str_encoded.split("'")[1][-10:]
# Out:
# ('/9j/4AAQSk', 'FYo7IH/9k=')

# %%
test_base = base64.b64decode(str_encoded.split("'")[1])

# %%
type(test_base)
# Out:
# bytes

# %%
bytes_image = io.BytesIO(test_base)
img = mpimg.imread(bytes_image, format="JPG")
img.shape
# Out:
# (756, 1008, 3)

# %%
plt.imshow(img)
plt.show()
